# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
import datetime
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('Coustomer Segmentation.xlsx')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID     135080
# Description      1454
# InvoiceNo           0
# StockCode           0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# Country             0
# dtype: int64

# %%
df=df.dropna()
df.isnull().sum().sort_values(ascending=False)
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %%
df.describe()

# we can see that quantuity has negative values
# Out:
#             Quantity      UnitPrice     CustomerID
# count  406829.000000  406829.000000  406829.000000
# mean       12.061303       3.460471   15287.690570
# std       248.693370      69.315162    1713.600303
# min    -80995.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13953.000000
# 50%         5.000000       1.950000   15152.000000
# 75%        12.000000       3.750000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
for i in df.columns:
    print(i , '=' , len(df[i].unique()))
# Out:
# InvoiceNo = 22190
# StockCode = 3684
# Description = 3896
# Quantity = 436
# InvoiceDate = 20460
# UnitPrice = 620
# CustomerID = 4372
# Country = 37

# %%
df=df.drop(df[df['Quantity']<0].index)

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  397924.000000  397924.000000  397924.000000
# mean       13.021823       3.116174   15294.315171
# std       180.420210      22.096788    1713.169877
# min         1.000000       0.000000   12346.000000
# 25%         2.000000       1.250000   13969.000000
# 50%         6.000000       1.950000   15159.000000
# 75%        12.000000       3.750000   16795.000000
# max     80995.000000    8142.750000   18287.000000

# %%
# adding a column named amount spent
df['AmountSpent']=df['Quantity']*df['UnitPrice']

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  AmountSpent
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34

# %%
df['InvDay']=df['InvoiceDate'].dt.date
df['InvTime']=df['InvoiceDate'].dt.time
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  AmountSpent  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom        15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom        22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom        20.34
#
#    InvDate      InvDay   InvTime
# 0        1  2010-12-01  08:26:00
# 1        1  2010-12-01  08:26:00
# 2        1  2010-12-01  08:26:00
# 3        1  2010-12-01  08:26:00
# 4        1  2010-12-01  08:26:00

# %% [markdown]
# # EDA

# %%
# Top 5 Customers with the highest no of orders

tf=df.groupby(by=['CustomerID','Country'], as_index=False)['InvoiceNo'].count()
tf.sort_values(by='InvoiceNo', ascending=False).iloc[:5]
# Out:
#       CustomerID         Country  InvoiceNo
# 4019     17841.0  United Kingdom       7847
# 1888     14911.0            EIRE       5677
# 1298     14096.0  United Kingdom       5111
# 334      12748.0  United Kingdom       4596
# 1670     14606.0  United Kingdom       2700

# %%
# Highest money spent by customers
df.sort_values(by='AmountSpent', ascending=False).iloc[:5]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 222680    556444     22502       PICNIC BASKET WICKER 60 PIECES        60
# 173382    551697      POST                              POSTAGE         1
# 348325    567423     23243  SET OF TEA COFFEE SUGAR TINS PANTRY      1412
#
#                InvoiceDate  UnitPrice  CustomerID         Country  \
# 540421 2011-12-09 09:15:00       2.08     16446.0  United Kingdom
# 61619  2011-01-18 10:01:00       1.04     12346.0  United Kingdom
# 222680 2011-06-10 15:28:00     649.50     15098.0  United Kingdom
# 173382 2011-05-03 13:46:00    8142.75     16029.0  United Kingdom
# 348325 2011-09-20 11:05:00       5.06     17450.0  United Kingdom
#
#         AmountSpent  InvDate      InvDay   InvTime
# 540421    168469.60        9  2011-12-09  09:15:00
# 61619      77183.60       18  2011-01-18  10:01:00
# 222680     38970.00       10  2011-06-10  15:28:00
# 173382      8142.75        3  2011-05-03  13:46:00
# 348325      7144.72       20  2011-09-20  11:05:00
