# %% [markdown]
# <img src="fireblaze.jpg" width=250 height=200 />

# %% [markdown]
# ## <p style="font-family: Arial; font-size:1.4em;color:red; style='background :yellow'"> Assignment</p>

# %% [markdown]
# <span style='color:Red'> **About The Dataset(Sales Dataset)** </span>

# %% [markdown]
# Here are the definitions for a few of the columns:
# * **File_Type:** The value “Active” means that the particular product needs investigation
#
# * **SoldFlag:** The value 1 = sale, 0 = no sale in past six months
#
# * **SKU_number:** This is the unique identifier for each product.
#
# * **Order:** Just a sequential counter. Can be ignored.
#
# * **SoldFlag:** 1 = sold in past 6 mos. 0 = Not sold
#
# * **MarketingType:** Two categories of how we market the product.
#
# * **New_Release_Flag:** Any product that has had a future release (i.e., Release Number > 1)

# %% [markdown]
# <span style='color:Blue'> **Import the Required Libraries** </span>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %% [markdown]
# ### <span style='color:Blue'> **Question - 1.Read the Sales dataset and display the top five rows** </span>

# %%
df=pd.read_csv('Sales_data.csv')
df.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice
# 0          8         28.97        31.84
# 1         39          0.00        15.54
# 2         34         30.19        27.97
# 3         20        133.93        83.15
# 4         28          4.00        23.99

# %% [markdown]
# ### <span style='color:Blue'> **Question - 2. Display the central tendency, Dispersion, and Shape of Dataset** </span>

# %%
# 'df.describe()' gives us a quick statistical summary of the dataset

df.describe()
# Out:
#                Order    SKU_number      SoldFlag     SoldCount  ReleaseNumber  \
# count  198917.000000  1.989170e+05  75996.000000  75996.000000  198917.000000
# mean   106483.543242  8.613626e+05      0.171009      0.322306       3.412202
# std     60136.716784  8.699794e+05      0.376519      1.168615       3.864243
# min         2.000000  5.000100e+04      0.000000      0.000000       0.000000
# 25%     55665.000000  2.172520e+05      0.000000      0.000000       1.000000
# 50%    108569.000000  6.122080e+05      0.000000      0.000000       2.000000
# 75%    158298.000000  9.047510e+05      0.000000      0.000000       5.000000
# max    208027.000000  3.960788e+06      1.000000     73.000000      99.000000
#
#        New_Release_Flag  StrengthFactor       PriceReg    ReleaseYear  \
# count     198917.000000    1.989170e+05  198917.000000  198917.000000
# mean           0.642248    1.117115e+06      90.895243    2006.016414
# std            0.479340    1.522090e+06      86.736367       9.158331
# min            0.000000    6.275000e+00       0.000000       0.000000
# 25%            0.000000    1.614188e+05      42.000000    2003.000000
# 50%            1.000000    5.822240e+05      69.950000    2007.000000
# 75%            1.000000    1.430083e+06     116.000000    2011.000000
# max            1.000000    1.738445e+07   12671.480000    2018.000000
#
#            ItemCount   LowUserPrice    LowNetPrice
# count  198917.000000  198917.000000  198917.000000
# mean       41.426283      30.982487      46.832053
# std        37.541215      69.066155     128.513236
# min         0.000000       0.000000       0.000000
# 25%        21.000000       4.910000      17.950000
# 50%        32.000000      16.080000      33.980000
# 75%        50.000000      40.240000      55.490000
# max      2542.000000   14140.210000   19138.790000

# %%
# Measures of central tendency are -
# Mean
# Median
# Mode

# %%
# Mean of the Dataset
numcol=df[['PriceReg','ReleaseYear','ItemCount','LowUserPrice','LowNetPrice']]
numcol.mean()
# Out:
# PriceReg          90.895243
# ReleaseYear     2006.016414
# ItemCount         41.426283
# LowUserPrice      30.982487
# LowNetPrice       46.832053
# dtype: float64

# %%
# Median of the Dataset
numcol.median()
# Out:
# PriceReg          69.95
# ReleaseYear     2007.00
# ItemCount         32.00
# LowUserPrice      16.08
# LowNetPrice       33.98
# dtype: float64

# %%
# Mode of the Dataset
numcol.mode()
# Out:
#    PriceReg  ReleaseYear  ItemCount  LowUserPrice  LowNetPrice
# 0     49.95         2010         21           4.0          0.0

# %%
# Dispersion measures
# Standard deviation
# Variance

# %%
# Standard deviation
numcol.std()
# Out:
# PriceReg         86.736367
# ReleaseYear       9.158331
# ItemCount        37.541215
# LowUserPrice     69.066155
# LowNetPrice     128.513236
# dtype: float64

# %%
# Variance
numcol.var()
# Out:
# PriceReg         7523.197307
# ReleaseYear        83.875030
# ItemCount        1409.342820
# LowUserPrice     4770.133814
# LowNetPrice     16515.651882
# dtype: float64

# %%
# Shape of the Dataset

df.shape
# Out:
# (198917, 14)

# %% [markdown]
# ### 1. Missing Value Analysis

# %% [markdown]
# ### <span style='color:Blue'> **Question - 3. Our dataset any missing values? If Yes then how many and which feature has a missing value** </span>

# %%
df.isnull().sum()
# Out:
# Order                    0
# File_Type                0
# SKU_number               0
# SoldFlag            122921
# SoldCount           122921
# MarketingType            0
# ReleaseNumber            0
# New_Release_Flag         0
# StrengthFactor           0
# PriceReg                 0
# ReleaseYear              0
# ItemCount                0
# LowUserPrice             0
# LowNetPrice              0
# dtype: int64

# %%
# we can see that "SoldFlag" and "SoldCount" columns both have 122921 missing or null values

# %% [markdown]
# ### <span style='color:Blue'> **Question - 4. Find a list of all the columns which have more than 50% of their values missing** </span>

# %%
df.isnull().sum()/len(df)*100
# Out:
# Order                0.000000
# File_Type            0.000000
# SKU_number           0.000000
# MarketingType        0.000000
# ReleaseNumber        0.000000
# New_Release_Flag     0.000000
# StrengthFactor       0.000000
# PriceReg             0.000000
# ReleaseYear          0.000000
# ItemCount            0.000000
# LowUserPrice         0.000000
# LowNetPrice          0.000000
# SoldFlag            61.795121
# SoldCount           61.795121
# dtype: float64

# %%
# we can see that "SoldFlag" and "SoldCount" columns both have 61.79% missing or null values  
# which implies that these two columns have more than 50% values missing

# %% [markdown]
# ### <span style='color:Blue'> **Question - 5. View the missing values within the data.** </span>
# <br> Hint : Heatmap

# %%
sns.heatmap(df.isnull());

# %% [markdown]
# ### 2. Dealing with missing values.

# %% [markdown]
# ### <span style='color:Blue'> **Question - 6. Remove all records if no more than 2 observations have been recorded.** </span>

# %%
df.dropna(thresh=2)
df.shape
# Out:
# (198917, 14)

# %% [markdown]
# ### <span style='color:Blue'> **Question - 7. Discard unnecessary columns of data.** </span>

# %%
df.drop(['SoldCount'],axis=1)
# Out:
#          Order   File_Type  SKU_number  SoldFlag MarketingType  ReleaseNumber  \
# 0            2  Historical     1737127       0.0             D             15
# 1            3  Historical     3255963       0.0             D              7
# 2            4  Historical      612701       0.0             D              0
# 3            6  Historical      115883       1.0             D              4
# 4            7  Historical      863939       1.0             D              2
# ...        ...         ...         ...       ...           ...            ...
# 198912  208023      Active      109683       NaN             D              7
# 198913  208024      Active      416462       NaN             D              8
# 198914  208025      Active      658242       NaN             S              2
# 198915  208026      Active     2538340       NaN             S              2
# 198916  208027      Active      416662       NaN             D             15
#
#         New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  ItemCount  \
# 0                      1    6.827430e+05     44.99         2015          8
# 1                      1    1.016014e+06     24.81         2005         39
# 2                      0    3.404640e+05     46.00         2013         34
# 3                      1    3.340110e+05    100.00         2006         20
# 4                      1    1.287938e+06    121.95         2010         28
# ...                  ...             ...       ...          ...        ...
# 198912                 1    2.101869e+05     72.87         2006         54
# 198913                 1    4.555041e+05    247.00         2009         65
# 198914                 1    1.692746e+05     50.00         2012         23
# 198915                 1    3.775266e+05     46.95         2001         23
# 198916                 1    1.183068e+05    120.00         2010         44
#
#         LowUserPrice  LowNetPrice
# 0              28.97        31.84
# 1               0.00        15.54
# 2              30.19        27.97
# 3             133.93        83.15
# 4               4.00        23.99
# ...              ...          ...
# 198912          8.46        60.59
# 198913          8.40        74.85
# 198914         23.98        32.62
# 198915         27.42        37.89
# 198916         10.97        60.67
#
# [198917 rows x 13 columns]

# %% [markdown]
# ### <span style='color:Blue'> **Question - 8.Is there any feature in the dataset that could be exempted from dealing with outliers?** </span>

# %%
sns.boxplot(data=df,x='Order');

# %% [markdown]
# ### <span style='color:Blue'> **Question - 9.How do I check the outliers for the feature showing the low net price?** </span>

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data=df, x='LowNetPrice');

# %% [markdown]
# ### <span style='color:Blue'> **Question - 10.Find out optimal value of K and minimize the outliers.?** </span>

# %%
df['lnp_value']=np.log(df['LowNetPrice'])
Q1=df['lnp_value'].quantile(0.25)
Q3=df['lnp_value'].quantile(0.75)
IQR=Q3-Q1
LL=Q1-3*IQR
UL=Q3+3*IQR
df=df[(df['lnp_value']<UL)&(df['lnp_value']>LL)]
df.head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arraylike.py:397: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice  lnp_value
# 0          8         28.97        31.84   3.460723
# 1         39          0.00        15.54   2.743417
# 2         34         30.19        27.97   3.331133
# 3         20        133.93        83.15   4.420646
# 4         28          4.00        23.99   3.177637

# %% [markdown]
# ### <span style='color:Blue'> **Question - 11.Suggest a method for finding outliers for the feature representing the number of sku number.?** </span>

# %%
plt.figure(figsize=(15,6))
sns.boxplot(data=df, x='SKU_number');

# %% [markdown]
# ### <span style='color:Blue'> **Question - 12.Which method allows you to retrieve the corresponding record within the data.?** </span>

# %%
# We can use loc[] or iloc[] method to retrieve the corresponding record within the data.

# %% [markdown]
# ### <span style='color:Blue'> **Question - 13.Calculate the standard score of Release Number?** </span>

# %%
from scipy.stats import zscore
df1=df
df1['zscore']= zscore(df1['ReleaseNumber'])
df1.sample(20)
# Out:
#          Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 38594    42731  Historical      349933       0.0        0.0             S
# 1208      1216  Historical     1457312       0.0        0.0             D
# 6816      7051  Historical      344345       0.0        0.0             D
# 175689  184800      Active      254512       NaN        NaN             D
# 8147      8404  Historical      157939       0.0        0.0             D
# 150117  159228      Active      169444       NaN        NaN             D
# 177620  186731      Active      200038       NaN        NaN             D
# 136699  145810      Active      555837       NaN        NaN             D
# 35609    36735  Historical      132186       0.0        0.0             S
# 153307  162418      Active      143013       NaN        NaN             S
# 57595    64144  Historical      861278       0.0        0.0             S
# 57286    63804  Historical      911781       0.0        0.0             S
# 174717  183828      Active      537605       NaN        NaN             D
# 141335  150446      Active      213090       NaN        NaN             D
# 107130  116241      Active      665595       NaN        NaN             S
# 172855  181966      Active       53881       NaN        NaN             D
# 154740  163851      Active       51489       NaN        NaN             D
# 148110  157221      Active      115628       NaN        NaN             S
# 28684    29308  Historical      651993       0.0        0.0             D
# 108136  117247      Active      865730       NaN        NaN             S
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# 38594              11                 1    7.716547e+06     75.95
# 1208                5                 1    3.652803e+06     83.80
# 6816                6                 1    4.569032e+06      0.00
# 175689              4                 1    1.430801e+05    138.95
# 8147                1                 0    2.372412e+06     48.95
# 150117              8                 1    3.653736e+05    429.95
# 177620              6                 1    3.655285e+05    211.95
# 136699              2                 1    2.854670e+06     92.00
# 35609               3                 1    1.205325e+06    129.00
# 153307              3                 1    1.364168e+06    199.00
# 57595               2                 1    1.658911e+06     49.99
# 57286               1                 0    1.504139e+06     39.95
# 174717              5                 1    5.012373e+03    204.00
# 141335              0                 0    1.964989e+06     42.95
# 107130              0                 0    1.464808e+04     39.00
# 172855              9                 1    2.274515e+05     31.98
# 154740             13                 1    9.562056e+04     73.60
# 148110              3                 1    1.116105e+05     60.40
# 28684               2                 1    1.034888e+06     41.95
# 108136              2                 1    5.768737e+05     25.99
#
#         ReleaseYear  ItemCount  LowUserPrice  LowNetPrice  lnp_value    zscore
# 38594          1995         18          5.67        47.23   3.855029  1.948222
# 1208           2010         10         88.11       790.37   6.672501  0.401276
# 6816           2006         24         81.51        93.55   4.538496  0.659100
# 175689         2010         94          4.21         4.34   1.467874  0.143451
# 8147           2001         37         37.92        13.94   2.634762 -0.630022
# 150117         2007        102          4.00        19.49   2.969902  1.174749
# 177620         2007         34         13.14        84.91   4.441592  0.659100
# 136699         2004         28          4.00        10.27   2.329227 -0.372197
# 35609          2005         26          0.00        48.84   3.888550 -0.114373
# 153307         2006         28          5.17        72.93   4.289500 -0.114373
# 57595          2013         40          5.08        13.74   2.620311 -0.372197
# 57286          2004         36         30.96        13.98   2.637628 -0.630022
# 174717         2012        177          8.99        35.97   3.582685  0.401276
# 141335         2005         23          5.71        36.81   3.605770 -0.887846
# 107130         2010         30         23.45        29.17   3.373141 -0.887846
# 172855         2009         75          4.00        23.99   3.177637  1.432573
# 154740         2008        162          4.00        26.14   3.263467  2.463871
# 148110         2003         50         12.68        81.63   4.402197 -0.114373
# 28684          2006         25         27.07        25.59   3.242202 -0.372197
# 108136         2011         28          4.00        59.10   4.079231 -0.372197

# %% [markdown]
# ### <span style='color:Blue'> **Question - 14.In marketing type which items are more sellable.** </span>
#
# NOTE:- Show the output in visualization

# %%
sns.displot(x='MarketingType', data=df1);

# %%
# Items with marketing type S are more sellable

# %% [markdown]
# ### <span style='color:Blue'> **Question - 15.Find out bias of soldflag based on release number?** </span>
#
# NOTE:- Box Plot.

# %%
plt.figure(figsize=(20,5))
sns.boxplot(data=df1, x='SoldFlag',y='ReleaseNumber');

# %% [markdown]
# ### <span style='color:Blue'> **Question - 16.Find out missing values and fill with zero?** </span>

# %%
df1.fillna(0)
# Out:
#          Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0            2  Historical     1737127       0.0        0.0             D
# 1            3  Historical     3255963       0.0        0.0             D
# 2            4  Historical      612701       0.0        0.0             D
# 3            6  Historical      115883       1.0        1.0             D
# 4            7  Historical      863939       1.0        1.0             D
# ...        ...         ...         ...       ...        ...           ...
# 198912  208023      Active      109683       0.0        0.0             D
# 198913  208024      Active      416462       0.0        0.0             D
# 198914  208025      Active      658242       0.0        0.0             S
# 198915  208026      Active     2538340       0.0        0.0             S
# 198916  208027      Active      416662       0.0        0.0             D
#
#         ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  \
# 0                  15                 1    6.827430e+05     44.99
# 1                   7                 1    1.016014e+06     24.81
# 2                   0                 0    3.404640e+05     46.00
# 3                   4                 1    3.340110e+05    100.00
# 4                   2                 1    1.287938e+06    121.95
# ...               ...               ...             ...       ...
# 198912              7                 1    2.101869e+05     72.87
# 198913              8                 1    4.555041e+05    247.00
# 198914              2                 1    1.692746e+05     50.00
# 198915              2                 1    3.775266e+05     46.95
# 198916             15                 1    1.183068e+05    120.00
#
#         ReleaseYear  ItemCount  LowUserPrice  LowNetPrice  lnp_value    zscore
# 0              2015          8         28.97        31.84   3.460723  2.979519
# 1              2005         39          0.00        15.54   2.743417  0.916924
# 2              2013         34         30.19        27.97   3.331133 -0.887846
# 3              2006         20        133.93        83.15   4.420646  0.143451
# 4              2010         28          4.00        23.99   3.177637 -0.372197
# ...             ...        ...           ...          ...        ...       ...
# 198912         2006         54          8.46        60.59   4.104130  0.916924
# 198913         2009         65          8.40        74.85   4.315486  1.174749
# 198914         2012         23         23.98        32.62   3.484926 -0.372197
# 198915         2001         23         27.42        37.89   3.634687 -0.372197
# 198916         2010         44         10.97        60.67   4.105449  2.979519
#
# [192075 rows x 16 columns]

# %% [markdown]
# ### <span style='color:Blue'> **Question - 17.How many value are active and historical in File_Type column ?** </span>
#
# NOTE:- Explain in brief from graph.

# %%
df1['File_Type'].value_counts()
# Out:
# Active        118369
# Historical     73706
# Name: File_Type, dtype: int64

# %%
df1['File_Type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### <span style='color:Blue'> **Question - 18. How many features are positive and negatively correlated?** </span>
#
# NOTE:- Explain with values and plot the corrleation values.

# %%
plt.figure(figsize=(11,7))
sns.heatmap(df1.corr(),annot=True);

# %% [markdown]
# ### <span style='color:Blue'> **Question - 19. Show the corrleation between 0 and 1.** </span>

# %%
df1.corr()
# Out:
#                      Order  SKU_number  SoldFlag  SoldCount  ReleaseNumber  \
# Order             1.000000    0.045165 -0.174267  -0.122051      -0.051544
# SKU_number        0.045165    1.000000 -0.109641  -0.075020      -0.216194
# SoldFlag         -0.174267   -0.109641  1.000000   0.618850       0.077915
# SoldCount        -0.122051   -0.075020  0.618850   1.000000       0.059219
# ReleaseNumber    -0.051544   -0.216194  0.077915   0.059219       1.000000
# New_Release_Flag -0.049335   -0.305282  0.009287  -0.001353       0.559952
# StrengthFactor   -0.150731    0.161495 -0.147906  -0.113258      -0.067220
# PriceReg         -0.055001   -0.160160  0.084345   0.057843       0.176652
# ReleaseYear       0.037367   -0.110654  0.073253   0.071450       0.114793
# ItemCount         0.022130   -0.265231  0.239829   0.231955       0.173502
# LowUserPrice     -0.298476   -0.062532  0.058557   0.044041       0.085305
# LowNetPrice      -0.042142    0.064750 -0.025548  -0.024083       0.042935
# lnp_value        -0.030624    0.071828 -0.016091  -0.016556       0.046496
# zscore           -0.051544   -0.216194  0.077915   0.059219       1.000000
#
#                   New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# Order                    -0.049335       -0.150731 -0.055001     0.037367
# SKU_number               -0.305282        0.161495 -0.160160    -0.110654
# SoldFlag                  0.009287       -0.147906  0.084345     0.073253
# SoldCount                -0.001353       -0.113258  0.057843     0.071450
# ReleaseNumber             0.559952       -0.067220  0.176652     0.114793
# New_Release_Flag          1.000000       -0.020799  0.170895     0.064848
# StrengthFactor           -0.020799        1.000000  0.038360    -0.275198
# PriceReg                  0.170895        0.038360  1.000000    -0.014692
# ReleaseYear               0.064848       -0.275198 -0.014692     1.000000
# ItemCount                 0.159208       -0.253803  0.077981     0.034057
# LowUserPrice              0.084435        0.021801  0.141139     0.021970
# LowNetPrice               0.041859        0.105044  0.291345    -0.038620
# lnp_value                 0.058927        0.065116  0.313872    -0.039613
# zscore                    0.559952       -0.067220  0.176652     0.114793
#
#                   ItemCount  LowUserPrice  LowNetPrice  lnp_value    zscore
# Order              0.022130     -0.298476    -0.042142  -0.030624 -0.051544
# SKU_number        -0.265231     -0.062532     0.064750   0.071828 -0.216194
# SoldFlag           0.239829      0.058557    -0.025548  -0.016091  0.077915
# SoldCount          0.231955      0.044041    -0.024083  -0.016556  0.059219
# ReleaseNumber      0.173502      0.085305     0.042935   0.046496  1.000000
# New_Release_Flag   0.159208      0.084435     0.041859   0.058927  0.559952
# StrengthFactor    -0.253803      0.021801     0.105044   0.065116 -0.067220
# PriceReg           0.077981      0.141139     0.291345   0.313872  0.176652
# ReleaseYear        0.034057      0.021970    -0.038620  -0.039613  0.114793
# ItemCount          1.000000      0.002704    -0.159289  -0.231812  0.173502
# LowUserPrice       0.002704      1.000000     0.099154   0.111197  0.085305
# LowNetPrice       -0.159289      0.099154     1.000000   0.754088  0.042935
# lnp_value         -0.231812      0.111197     0.754088   1.000000  0.046496
# zscore             0.173502      0.085305     0.042935   0.046496  1.000000

# %% [markdown]
# ### <span style='color:Blue'> **Question - 20. Summaries the data with categorical variable.** </span>

# %%
# df1.describe(include='all')
df1.describe(include='object')
# Out:
#        File_Type MarketingType
# count     192075        192075
# unique         2             2
# top       Active             S
# freq      118369         96709

# %% [markdown]
# ### <span style='color:Blue'> **Question - 21. Calculate the mean and median of SKU_number.** </span>

# %%
# Mean
print('The mean of SKU_number is',df1['SKU_number'].mean())
# Out:
# The mean of SKU_number is 866877.1238474554

# %%
# Median
print('The median of SKU_number is',df1['SKU_number'].median())
# Out:
# The median of SKU_number is 612199.0

# %% [markdown]
# ### <span style='color:Blue'> **Question - 22. Calculate the mean and median of PriceCount.** </span>

# %%
# Mean
print('The mean of PriceReg is',df1['PriceReg'].mean())
# Out:
# The mean of PriceReg is 91.59467676677717

# %%
# Median
print('The median of PriceReg is',df1['PriceReg'].median())
# Out:
# The median of PriceReg is 69.95

# %% [markdown]
# ### <span style='color:Blue'> **Question - 23.Convert the File_Type columns to numerical.** </span>

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
df1['FileType_LE']=LE.fit_transform(df1['File_Type'])
df1.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice  lnp_value    zscore  FileType_LE
# 0          8         28.97        31.84   3.460723  2.979519            1
# 1         39          0.00        15.54   2.743417  0.916924            1
# 2         34         30.19        27.97   3.331133 -0.887846            1
# 3         20        133.93        83.15   4.420646  0.143451            1
# 4         28          4.00        23.99   3.177637 -0.372197            1

# %%
df1['File_Type'].unique()
# Out:
# array(['Historical', 'Active'], dtype=object)

# %%
df1['FileType_LE'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# ### <span style='color:Blue'> **Question - 24.Handle the remaining categorical data.** </span>

# %%
df1['MarketingType_LE']=LE.fit_transform(df1['MarketingType'])
df1.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical     1737127       0.0        0.0             D
# 1      3  Historical     3255963       0.0        0.0             D
# 2      4  Historical      612701       0.0        0.0             D
# 3      6  Historical      115883       1.0        1.0             D
# 4      7  Historical      863939       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1        682743.0     44.99         2015
# 1              7                 1       1016014.0     24.81         2005
# 2              0                 0        340464.0     46.00         2013
# 3              4                 1        334011.0    100.00         2006
# 4              2                 1       1287938.0    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice  lnp_value    zscore  FileType_LE  \
# 0          8         28.97        31.84   3.460723  2.979519            1
# 1         39          0.00        15.54   2.743417  0.916924            1
# 2         34         30.19        27.97   3.331133 -0.887846            1
# 3         20        133.93        83.15   4.420646  0.143451            1
# 4         28          4.00        23.99   3.177637 -0.372197            1
#
#    MarketingType_LE
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0

# %% [markdown]
# ### <span style='color:Blue'> **Question - 25.Normalize the data.** </span>

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df1['StrengthFactor']=ss.fit_transform(df1['StrengthFactor'].array.reshape(-1,1))
df1['SKU_number']=ss.fit_transform(df1['SKU_number'].array.reshape(-1,1))

# %%
df1.head()
# Out:
#    Order   File_Type  SKU_number  SoldFlag  SoldCount MarketingType  \
# 0      2  Historical    0.994743       0.0        0.0             D
# 1      3  Historical    2.730855       0.0        0.0             D
# 2      4  Historical   -0.290537       0.0        0.0             D
# 3      6  Historical   -0.858427       1.0        1.0             D
# 4      7  Historical   -0.003358       1.0        1.0             D
#
#    ReleaseNumber  New_Release_Flag  StrengthFactor  PriceReg  ReleaseYear  \
# 0             15                 1       -0.290363     44.99         2015
# 1              7                 1       -0.066430     24.81         2005
# 2              0                 0       -0.520349     46.00         2013
# 3              4                 1       -0.524684    100.00         2006
# 4              2                 1        0.116282    121.95         2010
#
#    ItemCount  LowUserPrice  LowNetPrice  lnp_value    zscore  FileType_LE  \
# 0          8         28.97        31.84   3.460723  2.979519            1
# 1         39          0.00        15.54   2.743417  0.916924            1
# 2         34         30.19        27.97   3.331133 -0.887846            1
# 3         20        133.93        83.15   4.420646  0.143451            1
# 4         28          4.00        23.99   3.177637 -0.372197            1
#
#    MarketingType_LE
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
